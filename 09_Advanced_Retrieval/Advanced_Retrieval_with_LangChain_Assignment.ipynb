# %% [markdown]
# # Advanced Retrieval with LangChain
#
# In the following notebook, we'll explore various methods of advanced retrieval using LangChain!
#
# We'll touch on:
#
# - Naive Retrieval
# - Best-Matching 25 (BM25)
# - Multi-Query Retrieval
# - Parent-Document Retrieval
# - Contextual Compression (a.k.a. Rerank)
# - Ensemble Retrieval
# - Semantic chunking
#
# We'll also discuss how these methods impact performance on our set of documents with a simple RAG chain.
#
# There will be two breakout rooms:
#
# - 🤝 Breakout Room Part #1
#   - Task 1: Getting Dependencies!
#   - Task 2: Data Collection and Preparation
#   - Task 3: Setting Up QDrant!
#   - Task 4-10: Retrieval Strategies
# - 🤝 Breakout Room Part #2
#   - Activity: Evaluate with Ragas

# %% [markdown]
# # 🤝 Breakout Room Part #1

# %% [markdown]
# ## Task 1: Getting Dependencies!
#
# We're going to need a few specific LangChain community packages, like OpenAI (for our [LLM](https://platform.openai.com/docs/models) and [Embedding Model](https://platform.openai.com/docs/guides/embeddings)) and Cohere (for our [Reranker](https://cohere.com/rerank)).

# %% [markdown]
# We'll also provide our OpenAI key, as well as our Cohere API key.

# %%
import os
import getpass

os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API Key:")

# %%
os.environ["COHERE_API_KEY"] = getpass.getpass("Cohere API Key:")

# %% [markdown]
# ## Task 2: Data Collection and Preparation
#
# We'll be using our Loan Data once again - this time the strutured data available through the CSV!

# %% [markdown]
# ### Data Preparation
#
# We want to make sure all our documents have the relevant metadata for the various retrieval strategies we're going to be applying today.

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader
from datetime import datetime, timedelta

loader = CSVLoader(
    file_path=f"./data/complaints.csv",
    metadata_columns=[
      "Date received", 
      "Product", 
      "Sub-product", 
      "Issue", 
      "Sub-issue", 
      "Consumer complaint narrative", 
      "Company public response", 
      "Company", 
      "State", 
      "ZIP code", 
      "Tags", 
      "Consumer consent provided?", 
      "Submitted via", 
      "Date sent to company", 
      "Company response to consumer", 
      "Timely response?", 
      "Consumer disputed?", 
      "Complaint ID"
    ]
)

loan_complaint_data = loader.load()

for doc in loan_complaint_data:
    doc.page_content = doc.metadata["Consumer complaint narrative"]

# %% [markdown]
# Let's look at an example document to see if everything worked as expected!

# %%
loan_complaint_data[0]
# Out:
# Document(metadata={'source': './data/complaints.csv', 'row': 0, 'Date received': '03/27/25', 'Product': 'Student loan', 'Sub-product': 'Federal student loan servicing', 'Issue': 'Dealing with your lender or servicer', 'Sub-issue': 'Trouble with how payments are being handled', 'Consumer complaint narrative': "The federal student loan COVID-19 forbearance program ended in XX/XX/XXXX. However, payments were not re-amortized on my federal student loans currently serviced by Nelnet until very recently. The new payment amount that is effective starting with the XX/XX/XXXX payment will nearly double my payment from {$180.00} per month to {$360.00} per month. I'm fortunate that my current financial position allows me to be able to handle the increased payment amount, but I am sure there are likely many borrowers who are not in the same position. The re-amortization should have occurred once the forbearance ended to reduce the impact to borrowers.", 'Company public response': 'None', 'Company': 'Nelnet, Inc.', 'State': 'IL', 'ZIP code': '60030', 'Tags': 'None', 'Consumer consent provided?': 'Consent provided', 'Submitted via': 'Web', 'Date sent to company': '03/27/25', 'Company response to consumer': 'Closed with explanation', 'Timely response?': 'Yes', 'Consumer disputed?': 'N/A', 'Complaint ID': '12686613'}, page_content="The federal student loan COVID-19 forbearance program ended in XX/XX/XXXX. However, payments were not re-amortized on my federal student loans currently serviced by Nelnet until very recently. The new payment amount that is effective starting with the XX/XX/XXXX payment will nearly double my payment from {$180.00} per month to {$360.00} per month. I'm fortunate that my current financial position allows me to be able to handle the increased payment amount, but I am sure there are likely many borrowers who are not in the same position. The re-amortization should have occurred once the forbearance ended to reduce the impact to borrowers.")

# %% [markdown]
# ## Task 3: Setting up QDrant!
#
# Now that we have our documents, let's create a QDrant VectorStore with the collection name "LoanComplaints".
#
# We'll leverage OpenAI's [`text-embedding-3-small`](https://openai.com/blog/new-embedding-models-and-api-updates) because it's a very powerful (and low-cost) embedding model.
#
# > NOTE: We'll be creating additional vectorstores where necessary, but this pattern is still extremely useful.

# %%
from langchain_community.vectorstores import Qdrant
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

vectorstore = Qdrant.from_documents(
    loan_complaint_data,
    embeddings,
    location=":memory:",
    collection_name="LoanComplaints"
)

# %% [markdown]
# ## Task 4: Naive RAG Chain
#
# Since we're focusing on the "R" in RAG today - we'll create our Retriever first.

# %% [markdown]
# ### R - Retrieval
#
# This naive retriever will simply look at each review as a document, and use cosine-similarity to fetch the 10 most relevant documents.
#
# > NOTE: We're choosing `10` as our `k` here to provide enough documents for our reranking process later

# %%
naive_retriever = vectorstore.as_retriever(search_kwargs={"k" : 10})

# %% [markdown]
# ### A - Augmented
#
# We're going to go with a standard prompt for our simple RAG chain today! Nothing fancy here, we want this to mostly be about the Retrieval process.

# %%
from langchain_core.prompts import ChatPromptTemplate

RAG_TEMPLATE = """\
You are a helpful and kind assistant. Use the context provided below to answer the question.

If you do not know the answer, or are unsure, say you don't know.

Query:
{question}

Context:
{context}
"""

rag_prompt = ChatPromptTemplate.from_template(RAG_TEMPLATE)

# %% [markdown]
# ### G - Generation
#
# We're going to leverage `gpt-4.1-nano` as our LLM today, as - again - we want this to largely be about the Retrieval process.

# %%
from langchain_openai import ChatOpenAI

chat_model = ChatOpenAI(model="gpt-4.1-nano")

# %% [markdown]
# ### LCEL RAG Chain
#
# We're going to use LCEL to construct our chain.
#
# > NOTE: This chain will be exactly the same across the various examples with the exception of our Retriever!

# %%
from langchain_core.runnables import RunnablePassthrough
from operator import itemgetter
from langchain_core.output_parsers import StrOutputParser

naive_retrieval_chain = (
    # INVOKE CHAIN WITH: {"question" : "<<SOME USER QUESTION>>"}
    # "question" : populated by getting the value of the "question" key
    # "context"  : populated by getting the value of the "question" key and chaining it into the base_retriever
    {"context": itemgetter("question") | naive_retriever, "question": itemgetter("question")}
    # "context"  : is assigned to a RunnablePassthrough object (will not be called or considered in the next step)
    #              by getting the value of the "context" key from the previous step
    | RunnablePassthrough.assign(context=itemgetter("context"))
    # "response" : the "context" and "question" values are used to format our prompt object and then piped
    #              into the LLM and stored in a key called "response"
    # "context"  : populated by getting the value of the "context" key from the previous step
    | {"response": rag_prompt | chat_model, "context": itemgetter("context")}
)

# %% [markdown]
# Let's see how this simple chain does on a few different prompts.
#
# > NOTE: You might think that we've cherry picked prompts that showcase the individual skill of each of the retrieval strategies - you'd be correct!

# %%
naive_retrieval_chain.invoke({"question" : "What is the most common issue with loans?"})["response"].content
# Out:
# 'Based on the given context, the most common issues with loans, particularly student loans, involve errors and mismanagement such as:\n\n- Dealing with your lender or servicer, including receiving bad information, errors in loan balances, misapplied payments, and wrongful denials of payment plans.\n- Incorrect or misleading information on credit reports, including unauthorized transfers or updates, and discrepancies in loan balances and statuses.\n- Trouble with how payments are being handled, including the inability to apply payments correctly or pay down principal, often leading to prolonged debt and increased interest.\n- Problems with loan forgiveness, cancellation, or discharge processes, especially related to long-term forbearance and mismanaged repayment plans.\n- Discrepancies and inaccuracies in loan amounts, interest calculations, and account status updates.\n\nThus, a recurring theme is that the most common issue seems to be mismanagement and errors by loan servicers, leading to inaccurate balances, payment issues, and confusion about loan status.'

# %%
naive_retrieval_chain.invoke({"question" : "Did any complaints not get handled in a timely manner?"})["response"].content
# Out:
# 'Yes, based on the provided context, some complaints did not get handled in a timely manner. Specifically, there are instances where the response to complaints was delayed or absent:\n\n- Complaint ID 12709087 (MOHELA) received on 03/28/25 was marked as "Timely response?": No, indicating the response was not handled in time.\n- Complaint ID 13062402 (Nelnet, Inc.) received on 04/18/25 was marked as "Timely response?": Yes, so this one was handled promptly.\n- Complaint ID 12832400 (Maximus Federal Services, Inc.) received on 04/05/25 was marked as "Timely response?": Yes.\n- Complaint ID 12973003 (EdFinancial Services) received on 04/14/25 was marked as "Timely response?": Yes.\n- Other complaints similarly show varied timeliness, with at least one (MOHELA) explicitly indicating a delay.\n\nTherefore, yes, some complaints did not get handled in a timely manner.'

# %%
naive_retrieval_chain.invoke({"question" : "Why did people fail to pay back their loans?"})["response"].content
# Out:
# 'People failed to pay back their loans primarily due to issues such as:\n\n- Lack of proper communication from loan servicers about when repayment was to resume or transfer notifications, leading to unawareness of payment obligations.\n- Being placed into forbearance or deferment options that allowed interest to continue accruing, which increased the total debt and extended repayment periods.\n- Difficulties in adjusting or applying payments correctly, often resulting in interest accumulating faster than payments can reduce the principal.\n- Financial hardships such as stagnant wages, economic downturns, and personal circumstances (like unemployment or bankruptcy) making monthly payments unaffordable.\n- Mismanagement or miscommunication by loan servicers, including improper transfer of loans without notification or incorrect reporting to credit agencies, impacting credit scores and repayment ability.\n- Lack of information and transparency about loan terms, interest buildup, and repayment options, leading borrowers to be unaware of their actual debt status or their rights.\n\nOverall, these issues contribute to borrowers being unable to keep up with their loan payments, often resulting in increasing debt, damaged credit, and financial hardship.'

# %% [markdown]
# Overall, this is not bad! Let's see if we can make it better!

# %% [markdown]
# ## Task 5: Best-Matching 25 (BM25) Retriever
#
# Taking a step back in time - [BM25](https://www.nowpublishers.com/article/Details/INR-019) is based on [Bag-Of-Words](https://en.wikipedia.org/wiki/Bag-of-words_model) which is a sparse representation of text.
#
# In essence, it's a way to compare how similar two pieces of text are based on the words they both contain.
#
# This retriever is very straightforward to set-up! Let's see it happen down below!

# %%
from langchain_community.retrievers import BM25Retriever

bm25_retriever = BM25Retriever.from_documents(loan_complaint_data, )

# %% [markdown]
# We'll construct the same chain - only changing the retriever.

# %%
bm25_retrieval_chain = (
    {"context": itemgetter("question") | bm25_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_prompt | chat_model, "context": itemgetter("context")}
)

# %% [markdown]
# Let's look at the responses!

# %%
bm25_retrieval_chain.invoke({"question" : "What is the most common issue with loans?"})["response"].content
# Out:
# 'Based on the provided context, the most common issue with loans appears to be problems related to dealing with lenders or servicers, such as miscommunication, incorrect information, fees, payment application issues, or bad information about the loan. Several complaints highlight difficulties in managing payments, understanding balances, or loan validity, indicating these are frequent concerns.'

# %%
bm25_retrieval_chain.invoke({"question" : "Did any complaints not get handled in a timely manner?"})["response"].content
# Out:
# 'Based on the provided context, all the complaints listed indicate that the companies responded in a timely manner, with responses marked as "Yes" under the "Timely response?" field. There are no complaints in the data suggesting that any complaints were not handled in a timely manner.'

# %%
bm25_retrieval_chain.invoke({"question" : "Why did people fail to pay back their loans?"})["response"].content
# Out:
# 'People failed to pay back their loans for various reasons, including issues with loan servicing and communication, improper handling of payment plans, and lack of response from loan servicers. Some specific reasons include:\n\n- Being steered into wrong types of forbearances and not receiving proper discharge or settlement information.\n- Auto-enrolled payments being unintentionally canceled or not reinitiated, leading to missed payments.\n- Lack of communication or failure to receive notifications about loan status changes, such as transfers between servicers.\n- Errors or disputes regarding payments, with some payments being reversed or not recognized despite being made.\n- Loan servicers not responding to requests for forbearance or deferment, leading to continued billing and accumulation of interest.\n- In some cases, borrowers were unaware that their loans had been transferred or that autopayments had been discontinued, resulting in missed payments and damage to credit scores.\n\nOverall, the failure to pay back loans often involved systemic issues with communication, responsiveness, and proper management by the loan servicers, rather than outright borrower negligence.'

# %% [markdown]
# It's not clear that this is better or worse, if only we had a way to test this (SPOILERS: We do, the second half of the notebook will cover this)

# %% [markdown]
# #### ❓ Question #1:
#
# Give an example query where BM25 is better than embeddings and justify your answer.
#
# - `What are common complaints with the company Navient?`
#   - BM25 excels at quickly finding sources that contain very specific keywords (Navient). Embeddings are better for finding things that have similar semantic meaning but may not match exact words.

# %% [markdown]
# ## Task 6: Contextual Compression (Using Reranking)
#
# Contextual Compression is a fairly straightforward idea: We want to "compress" our retrieved context into just the most useful bits.
#
# There are a few ways we can achieve this - but we're going to look at a specific example called reranking.
#
# The basic idea here is this:
#
# - We retrieve lots of documents that are very likely related to our query vector
# - We "compress" those documents into a smaller set of *more* related documents using a reranking algorithm.
#
# We'll be leveraging Cohere's Rerank model for our reranker today!
#
# All we need to do is the following:
#
# - Create a basic retriever
# - Create a compressor (reranker, in this case)
#
# That's it!
#
# Let's see it in the code below!

# %%
from langchain.retrievers.contextual_compression import ContextualCompressionRetriever
from langchain_cohere import CohereRerank

compressor = CohereRerank(model="rerank-v3.5")
compression_retriever = ContextualCompressionRetriever(
    base_compressor=compressor, base_retriever=naive_retriever
)

# %% [markdown]
# Let's create our chain again, and see how this does!

# %%
contextual_compression_retrieval_chain = (
    {"context": itemgetter("question") | compression_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_prompt | chat_model, "context": itemgetter("context")}
)

# %%
contextual_compression_retrieval_chain.invoke({"question" : "What is the most common issue with loans?"})["response"].content
# Out:
# 'Based on the provided information, the most common issue with loans appears to be problems related to dealing with the lender or servicer, such as errors in loan balances, misapplied payments, wrongful denials of payment plans, and mishandling of loan information. These issues often involve inaccuracies, lack of communication, or unethical practices by loan servicers.'

# %%
contextual_compression_retrieval_chain.invoke({"question" : "Did any complaints not get handled in a timely manner?"})["response"].content
# Out:
# 'Based on the provided information, at least one complaint was handled in a timely manner. Specifically, the complaint regarding the issue with the payments not being applied to the loan account was responded to with a "Closed with explanation" status, and the response was marked as "Yes" for being timely. \n\nHowever, there are other complaints, such as the one about the delayed response to a request for account review and resolution, which has been pending for nearly 18 months without resolution. \n\nOverall, while some complaints were addressed promptly, others experienced significant delays.'

# %%
contextual_compression_retrieval_chain.invoke({"question" : "Why did people fail to pay back their loans?"})["response"].content
# Out:
# "People failed to pay back their loans primarily due to a combination of factors including lack of clear information about repayment obligations, unexpected or unnotified transfers of their loans, difficulties managing interest accumulation, and limited repayment options. Many borrowers were not adequately informed by financial aid officers or loan servicers about the necessity to repay loans, the impact of interest, or changes in their loan status. Additionally, options like forbearance or deferment, while accessible, often led to increasing interest that made repayment more difficult over time. Poor communication, complicated or mismatched account information, and the inability to qualify for forgiveness programs also contributed to borrowers' struggles in repaying their loans."

# %% [markdown]
# We'll need to rely on something like Ragas to help us get a better sense of how this is performing overall - but it "feels" better!

# %% [markdown]
# ## Task 7: Multi-Query Retriever
#
# Typically in RAG we have a single query - the one provided by the user.
#
# What if we had....more than one query!
#
# In essence, a Multi-Query Retriever works by:
#
# 1. Taking the original user query and creating `n` number of new user queries using an LLM.
# 2. Retrieving documents for each query.
# 3. Using all unique retrieved documents as context
#
# So, how is it to set-up? Not bad! Let's see it down below!

# %%
from langchain.retrievers.multi_query import MultiQueryRetriever

multi_query_retriever = MultiQueryRetriever.from_llm(
    retriever=naive_retriever, llm=chat_model
)

# %%
multi_query_retrieval_chain = (
    {"context": itemgetter("question") | multi_query_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_prompt | chat_model, "context": itemgetter("context")}
)

# %%
multi_query_retrieval_chain.invoke({"question" : "What is the most common issue with loans?"})["response"].content
# Out:
# 'Based on the provided complaints data, the most common issue with loans appears to be related to **mismanagement and errors by loan servicers**, including errors in loan balances, misapplied payments, wrongful denials of repayment plans, and inaccuracies in reporting to credit bureaus. Many complaints highlight problems such as incorrect account information, confusing transfer and servicing history, inaccurate loan amounts, and failure to provide proper validation or documentation of debts.\n\nAdditionally, recurring themes include:\n- **Trouble with how payments are being handled** (e.g., payments misapplied, inability to pay down principal, interest capitalization)\n- **Errors in loan balances and account information**\n- **Problems with repayment options and loan discharge or forgiveness**\n- **Inadequate or unresponsive customer service**\n- **Unauthorized access or privacy violations**\n\nGiven the prevalence of these issues, it seems that a major and most common problem is **servicer errors and mismanagement leading to inaccuracies, confusion, and difficulties for borrowers**.\n\nIf you need further assistance or specific insights, feel free to ask!'

# %%
multi_query_retrieval_chain.invoke({"question" : "Did any complaints not get handled in a timely manner?"})["response"].content
# Out:
# 'Based on the provided complaints data, several complaints indicate that issues were not handled in a timely manner. Specifically:\n\n- One complaint (Complaint ID: 12709087) submitted on 03/28/25 was not responded to promptly, with the response marked as "N/A" and responded to as "Closed with explanation," but it explicitly states "Timely response?": No.\n- Another complaint (Complaint ID: 12973003) received on 04/14/25 was handled timely ("Yes").\n- Multiple complaints from EdFinancial Services complainants involve delays of over a year or longer, such as those concerning unresolved disputes, delayed loan discharges, and unprocessed applications, with some complaints noting a delay of over 16 months and no resolution.\n\nIn summary, yes, there are complaints where issues were not handled in a timely manner, with some taken over a year, and instances where responses were delayed or never received within expected timeframes.'

# %%
multi_query_retrieval_chain.invoke({"question" : "Why did people fail to pay back their loans?"})["response"].content
# Out:
# "People failed to pay back their loans mainly due to a combination of factors illustrated in the complaints:\n\n1. Lack of clear information or guidance from lenders and servicers about repayment options, such as income-driven repayment plans or loan forgiveness programs, leading borrowers to remain in forbearance or rely on unaffordable repayment plans.\n2. Steered into long-term forbearances or forced into loan consolidation without being informed of better alternatives, which caused interest to capitalize and increased the total debt.\n3. Systemic issues and mismanagement by loan servicers, including improper handling of accounts, failure to notify borrowers of changes, or incorrect reporting of account statuses to credit bureaus.\n4. Rising interest and fees due to compounded interest during deferment or forbearance periods, making loans harder to repay and extending the repayment timeline.\n5. In some cases, borrowers experienced financial hardships such as job loss, homelessness, or medical issues that made consistent repayment impossible.\n6. Misleading or insufficient communication, leading borrowers to believe they had more manageable options, which were not fully explained or accessible.\n\nOverall, the inability to pay back loans was often not due to irresponsibility but rather systemic failures, miscommunication, and circumstances beyond borrowers' control."

# %% [markdown]
# #### ❓ Question #2:
#
# Explain how generating multiple reformulations of a user query can improve recall.
#
# - The user may have not asked the question very well. Maybe they used bad grammar or weren't very specific. The LLM can generate multiple questions that relate to their original request, and those may be better suited to our data. This will result in more (hopefully relevant) documents to be Retrieved. When used to Augment the original request, it may help Generate a more useful final response.

# %% [markdown]
# ## Task 8: Parent Document Retriever
#
# A "small-to-big" strategy - the Parent Document Retriever works based on a simple strategy:
#
# 1. Each un-split "document" will be designated as a "parent document" (You could use larger chunks of document as well, but our data format allows us to consider the overall document as the parent chunk)
# 2. Store those "parent documents" in a memory store (not a VectorStore)
# 3. We will chunk each of those documents into smaller documents, and associate them with their respective parents, and store those in a VectorStore. We'll call those "child chunks".
# 4. When we query our Retriever, we will do a similarity search comparing our query vector to the "child chunks".
# 5. Instead of returning the "child chunks", we'll return their associated "parent chunks".
#
# Okay, maybe that was a few steps - but the basic idea is this:
#
# - Search for small documents
# - Return big documents
#
# The intuition is that we're likely to find the most relevant information by limiting the amount of semantic information that is encoded in each embedding vector - but we're likely to miss relevant surrounding context if we only use that information.
#
# Let's start by creating our "parent documents" and defining a `RecursiveCharacterTextSplitter`.

# %%
from langchain.retrievers import ParentDocumentRetriever
from langchain.storage import InMemoryStore
from langchain_text_splitters import RecursiveCharacterTextSplitter
from qdrant_client import QdrantClient, models

parent_docs = loan_complaint_data
child_splitter = RecursiveCharacterTextSplitter(chunk_size=750)

# %% [markdown]
# We'll need to set up a new QDrant vectorstore - and we'll use another useful pattern to do so!
#
# > NOTE: We are manually defining our embedding dimension, you'll need to change this if you're using a different embedding model.

# %%
from langchain_qdrant import QdrantVectorStore

client = QdrantClient(location=":memory:")

client.create_collection(
    collection_name="full_documents",
    vectors_config=models.VectorParams(size=1536, distance=models.Distance.COSINE)
)

parent_document_vectorstore = QdrantVectorStore(
    collection_name="full_documents", embedding=OpenAIEmbeddings(model="text-embedding-3-small"), client=client
)

# %% [markdown]
# Now we can create our `InMemoryStore` that will hold our "parent documents" - and build our retriever!

# %%
store = InMemoryStore()

parent_document_retriever = ParentDocumentRetriever(
    vectorstore = parent_document_vectorstore,
    docstore=store,
    child_splitter=child_splitter,
)

# %% [markdown]
# By default, this is empty as we haven't added any documents - let's add some now!

# %%
parent_document_retriever.add_documents(parent_docs, ids=None)

# %% [markdown]
# We'll create the same chain we did before - but substitute our new `parent_document_retriever`.

# %%
parent_document_retrieval_chain = (
    {"context": itemgetter("question") | parent_document_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_prompt | chat_model, "context": itemgetter("context")}
)

# %% [markdown]
# Let's give it a whirl!

# %%
parent_document_retrieval_chain.invoke({"question" : "What is the most common issue with loans?"})["response"].content
# Out:
# 'Based on the provided context, the most common issues with loans involve problems related to the servicing and reporting of the loans. Specifically, the frequent issues include:\n\n- Incorrect or misleading information on credit reports, such as inaccurate account status or balances.\n- Discrepancies and errors in loan balances, interest rates, or payment application.\n- Misapplied payments and wrongful denials of payment plans.\n- Challenges with dealing with lenders or servicers, including disputes over fees or account legitimacy.\n- Errors resulting from loan transfers or sales, leading to confusion and unverified debt reporting.\n\nThese complaints indicate that a significant and recurring problem with loans is errors and mismanagement by loan servicers and lenders, which can negatively impact borrowers’ credit reports, balances, and overall financial stability.\n\nIf you have further questions or need more details, feel free to ask!'

# %%
parent_document_retrieval_chain.invoke({"question" : "Did any complaints not get handled in a timely manner?"})["response"].content
# Out:
# 'Based on the provided data, yes, there are complaints that were not handled in a timely manner. Specifically, the complaint regarding the student loan application with MOHELA received on 03/28/25 was marked as "Timely response?": No, indicating it was not handled promptly. Similarly, the complaint about difficulties with payments and forbearance with MOHELA received on 04/11/25 was also marked as "No" for timely response. \n\nTherefore, the answer is: Yes, some complaints did not get handled in a timely manner.'

# %%
parent_document_retrieval_chain.invoke({"question" : "Why did people fail to pay back their loans?"})["response"].content
# Out:
# 'People often fail to pay back their loans due to various reasons highlighted in the complaints. These include experiencing severe financial hardship after graduation, relying on deferment and forbearance options which increase interest, and being misled about the manageability and value of their education and loans. Additionally, some individuals face issues like the inability to find employment in their field, institutional misconduct by the educational institutions, and complications with loan servicing such as lack of proper notifications, disputes over debt legitimacy, and administrative errors. All these factors contribute to their difficulty in repaying loans.'

# %% [markdown]
# Overall, the performance *seems* largely the same. We can leverage a tool like [Ragas]() to more effectively answer the question about the performance.

# %% [markdown]
# ## Task 9: Ensemble Retriever
#
# In brief, an Ensemble Retriever simply takes 2, or more, retrievers and combines their retrieved documents based on a rank-fusion algorithm.
#
# In this case - we're using the [Reciprocal Rank Fusion](https://plg.uwaterloo.ca/~gvcormac/cormacksigir09-rrf.pdf) algorithm.
#
# Setting it up is as easy as providing a list of our desired retrievers - and the weights for each retriever.

# %%
from langchain.retrievers import EnsembleRetriever

retriever_list = [bm25_retriever, naive_retriever, parent_document_retriever, compression_retriever, multi_query_retriever]
equal_weighting = [1/len(retriever_list)] * len(retriever_list)

ensemble_retriever = EnsembleRetriever(
    retrievers=retriever_list, weights=equal_weighting
)

# %% [markdown]
# We'll pack *all* of these retrievers together in an ensemble.

# %%
ensemble_retrieval_chain = (
    {"context": itemgetter("question") | ensemble_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_prompt | chat_model, "context": itemgetter("context")}
)

# %% [markdown]
# Let's look at our results!

# %%
ensemble_retrieval_chain.invoke({"question" : "What is the most common issue with loans?"})["response"].content
# Out:
# 'Based on the provided complaints and issues reported, the most common issue with student loans appears to be **mismanagement and improper handling by loan servicers**, which includes:\n\n- Errors and lack of communication regarding loan balances and interest calculations\n- Unauthorized or unnotified transfers of loan servicing\n- Incorrect or outdated information on credit reports leading to credit score drops\n- Problems with applying payments correctly or paying more than owed\n- Inadequate or unhelpful customer service and failure to resolve issues\n- Dealing with false or bad information about loans\n- Issues with loan classification (e.g., FFELP vs. HEAL), in-school deferments, or misclassification\n- Problems with loan consolidation and lack of clear disclosure\n- Unauthorized access and possible account compromises\n\nThis pattern suggests that the most common and significant issue is **misadministration and poor communication by loan servicers, resulting in errors, confusion, and financial hardship for borrowers**. \n\nIf you need a specific summary: **The most common issue with student loans is mishandling by servicers, including errors, miscommunication, and improper account management, leading to financial and credit complications for borrowers.**'

# %%
ensemble_retrieval_chain.invoke({"question" : "Did any complaints not get handled in a timely manner?"})["response"].content
# Out:
# 'Based on the provided complaints, yes, some complaints indicate that complaints were not handled in a timely manner. For example, complaint ID 12709087 involving MOHELA notes a response that was "No" for timely response, indicating it was delayed. Similarly, complaint ID 12668396 regarding MOHELA\'s reporting issues was marked "No" for timely response.\n\nTherefore, the answer is: Yes, some complaints did not get handled in a timely manner.'

# %%
ensemble_retrieval_chain.invoke({"question" : "Why did people fail to pay back their loans?"})["response"].content
# Out:
# 'People failed to pay back their loans primarily due to a combination of factors including insufficient or misleading information about repayment terms, unanticipated interest accumulation, lack of proper communication from loan servicers, and financial hardships such as low income, unemployment, or unexpected life events. Many borrowers also faced difficulties understanding complex loan transfer processes, changes in servicers, or errors in loan balances and account statuses, which hampered their ability to make timely payments. Additionally, some borrowers experienced issues with their payment application, reverse payments, or mismanagement of their accounts, further complicating repayment efforts. Overall, systemic issues, inadequate transparency, and personal financial challenges contributed to the inability of some individuals to successfully repay their loans.'

# %% [markdown]
# ## Task 10: Semantic Chunking
#
# While this is not a retrieval method - it *is* an effective way of increasing retrieval performance on corpora that have clean semantic breaks in them.
#
# Essentially, Semantic Chunking is implemented by:
#
# 1. Embedding all sentences in the corpus.
# 2. Combining or splitting sequences of sentences based on their semantic similarity based on a number of [possible thresholding methods](https://python.langchain.com/docs/how_to/semantic-chunker/):
#   - `percentile`
#   - `standard_deviation`
#   - `interquartile`
#   - `gradient`
# 3. Each sequence of related sentences is kept as a document!
#
# Let's see how to implement this!

# %% [markdown]
# We'll use the `percentile` thresholding method for this example which will:
#
# Calculate all distances between sentences, and then break apart sequences of setences that exceed a given percentile among all distances.

# %%
from langchain_experimental.text_splitter import SemanticChunker

semantic_chunker = SemanticChunker(
    embeddings,
    breakpoint_threshold_type="percentile"
)

# %% [markdown]
# Now we can split our documents.

# %%
semantic_documents = semantic_chunker.split_documents(loan_complaint_data[:20])

# %% [markdown]
# Let's create a new vector store.

# %%
semantic_vectorstore = Qdrant.from_documents(
    semantic_documents,
    embeddings,
    location=":memory:",
    collection_name="Loan_Complaint_Data_Semantic_Chunks"
)

# %% [markdown]
# We'll use naive retrieval for this example.

# %%
semantic_retriever = semantic_vectorstore.as_retriever(search_kwargs={"k" : 10})

# %% [markdown]
# Finally we can create our classic chain!

# %%
semantic_retrieval_chain = (
    {"context": itemgetter("question") | semantic_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_prompt | chat_model, "context": itemgetter("context")}
)

# %% [markdown]
# And view the results!

# %%
semantic_retrieval_chain.invoke({"question" : "What is the most common issue with loans?"})["response"].content
# Out:
# 'The most common issue with loans, based on the provided complaints, appears to be problems related to miscommunication, errors, and mishandling by loan servicers. Specifically, many complaints involve:\n\n- Struggling to repay or handle payment plans (e.g., unexpected payment increases, problems with auto-debit setup)\n- Errors in account status, such as loans being mistakenly reported as in default or delinquent\n- Lack of transparency and poor communication from loan servicers\n- Disputes over incorrect reporting or credit information\n- Issues with loan forgiveness, discharge, or legal breaches related to personal data\n\nOverall, a recurring theme is inadequate communication and administrative errors by loan servicers causing stress, financial confusion, and incorrect credit reporting.'

# %%
semantic_retrieval_chain.invoke({"question" : "Did any complaints not get handled in a timely manner?"})["response"].content
# Out:
# 'Based on the provided complaints, it appears that several complaints involved delays or lack of timely responses from the companies. Specifically:\n\n- The complaint about Nelnet (Row 17) mentions that despite multiple letters being sent via Certified Mail, Nelnet never responded to the complaint or provided answers. The company\'s response was noted as "Closed with explanation," but there was no indication of a timely reply to the complaint itself, suggesting it was not handled promptly.\n- The complaint about Maximus Federal Services (Row 14) indicates that responses were "Closed with explanation," and the responses to the complaints are marked as "Yes" for timely response, suggesting that responses may have been timely in that case.\n- The complaint about EdFinancial Services (Row 4) also shows a "Closed with explanation" response, but the information provided does not specify whether the handling was delayed.\n\nGiven that one complaint explicitly notes that Nelnet did not respond despite multiple attempts and acknowledgment, it suggests that at least in this instance, some complaints did not get handled in a timely manner. \n\n**In summary:** Yes, there was at least one complaint (the one involving Nelnet) that was not handled in a timely manner, as the company did not respond to the consumer\'s repeated efforts despite acknowledgment of receipt.'

# %%
semantic_retrieval_chain.invoke({"question" : "Why did people fail to pay back their loans?"})["response"].content
# Out:
# 'People may fail to pay back their loans for various reasons, including issues related to miscommunication, lack of transparency from lenders or servicers, problems with loan documentation or verification, financial hardship, disputes over the legitimacy of their debt, or complications arising from legal or policy changes. \n\nFor example, some borrowers face difficulties due to receiving bad or unclear information about their loan status or repayment options, delays or errors in payment processing, or legal disputes over the validity or management of their loans. Others encounter issues related to collection practices or data breaches that affect their credit reports and ability to repay. \n\nIn some cases, borrowers also experience frustration when loan servicers are unresponsive or stall in providing clarification or assistance, which can contribute to their failure to meet repayment obligations. \n\nIf you need specific details from the provided context, I can elaborate further.'

# %% [markdown]
# #### ❓ Question #3:
#
# If sentences are short and highly repetitive (e.g., FAQs), how might semantic chunking behave, and how would you adjust the algorithm?
#
# - Short, highly repetitive sentences may all be lumped together into a few big chunks because they don't have much distance from each other. I would try the `gradient` threshold method ("useful when chunks are highly correlated with each other") and/or adjust `breakpoint_threshold_amount` and `min_chunk_size` parameters to get chunks split at an appropriate size.

# %% [markdown]
# # 🤝 Breakout Room Part #2

# %% [markdown]
# #### 🏗️ Activity #1
#
# Your task is to evaluate the various Retriever methods against eachother.
#
# You are expected to:
#
# 1. Create a "golden dataset"
#  - Use Synthetic Data Generation (powered by Ragas, or otherwise) to create this dataset
# 2. Evaluate each retriever with *retriever specific* Ragas metrics
#  - Semantic Chunking is not considered a retriever method and will not be required for marks, but you may find it useful to do a "semantic chunking on" vs. "semantic chunking off" comparision between them
# 3. Compile these in a list and write a small paragraph about which is best for this particular data and why.
#
# Your analysis should factor in:
#   - Cost
#   - Latency
#   - Performance
#
# > NOTE: This is **NOT** required to be completed in class. Please spend time in your breakout rooms creating a plan before moving on to writing code.

# %% [markdown]
# ##### HINTS:
#
# - LangSmith provides detailed information about latency and cost.

# %%
### YOUR CODE HERE
